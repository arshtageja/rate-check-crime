# %%
import pandas as pd
import numpy as np

data1=pd.read_csv('col1_26.csv')

# %%
data1
# Out:
#                                               Crime ID    Month  \
# 0                                                  NaN  2016-01
# 1                                                  NaN  2016-01
# 2                                                  NaN  2016-01
# 3                                                  NaN  2016-01
# 4    06ad59a65137a97eb1e9e979f1eb96f0d70935e584b3d1...  2016-01
# 5                                                  NaN  2016-01
# 6                                                  NaN  2016-01
# 7                                                  NaN  2016-01
# 8                                                  NaN  2016-01
# 9    0a89b47eef6f79a7fecde3eba636782f54783c91a74c27...  2016-01
# 10   9a0c55946ee3af03c5ac9d9329448af954317c897ea3ca...  2016-01
# 11   1dd469db3a236600afafe7c7d790c196ca82ff54ad569c...  2016-01
# 12   dbd8d486130bf1ae6cddc3e654874bcbe751fc8dac678e...  2016-01
# 13   6269c87621c12578331bfdb4890d73db078a57c9b8f7fd...  2016-01
# ...

# %%
data2=pd.read_csv('coloutcome1_26.csv')

# %%
data2
# Out:
#                                               Crime ID    Month  \
# 0    9a0874c4253249e9b19acf901553a1b2b283306a7d4e8e...  2016-01
# 1    cedbd8e53be09aedf425960b92532a605f81c5a3d68ecd...  2016-01
# 2    71e4ed14fa7cab036a6a071f05f3ce916c72f9277a2d46...  2016-01
# 3    37d129dcbffc39f2406456cd2db7d327368f43f2956155...  2016-01
# 4    fc64024e2cd4fff34e64e755bc61a05556d28315d91b11...  2016-01
# 5    75e335d991a5eb085420479a9d038ad00c8e3fa9a2d223...  2016-01
# 6    827fc230bc838a300c3acb4436f4ee4cfceef66dfdf152...  2016-01
# 7    2df6f856bca6c389479db341b14681eafc048449d394a4...  2016-01
# 8    83a20851c9195b72da4e521ae36af1b9056e593aa65051...  2016-01
# 9    754345ef727ec05d8e2a03f91094af535fa76dba69718c...  2016-01
# 10   40481ddf24e7fb8b550e400c1d8711c1e3e697e20c211c...  2016-01
# 11   cb09d1dff282a76c7fcc5439dc83912a11776b07e494e2...  2016-01
# 12   f935de2384d794eaf305a3d64842a7c216d69913136fc6...  2016-01
# 13   7f74a01f3acf0a504eca6aded526ca287a30e36871793b...  2016-01
# ...

# %%
data1.head(3)
# Out:
#   Crime ID    Month            Reported by           Falls within  Longitude  \
# 0      NaN  2016-01  City of London Police  City of London Police  -0.114954
# 1      NaN  2016-01  City of London Police  City of London Police  -0.112422
# 2      NaN  2016-01  City of London Police  City of London Police  -0.114954
#
#     Latitude                    Location  LSOA code    LSOA name  \
# 0  51.518632  On or near Brownlow Street  E01000914  Camden 028B
# 1  51.515381        On or near Star Yard  E01000914  Camden 028B
# 2  51.518632  On or near Brownlow Street  E01000914  Camden 028B
#
#               Crime type Last outcome category  Context
# 0  Anti-social behaviour                   NaN      NaN
# 1  Anti-social behaviour                   NaN      NaN
# 2  Anti-social behaviour                   NaN      NaN

# %%
data2.head(3)
# Out:
#                                             Crime ID    Month  \
# 0  9a0874c4253249e9b19acf901553a1b2b283306a7d4e8e...  2016-01
# 1  cedbd8e53be09aedf425960b92532a605f81c5a3d68ecd...  2016-01
# 2  71e4ed14fa7cab036a6a071f05f3ce916c72f9277a2d46...  2016-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.077596  51.515849
# 1  City of London Police  City of London Police  -0.106922  51.514204
# 2  City of London Police  City of London Police  -0.108231  51.513928
#
#                      Location  LSOA code            LSOA name  \
# 0   On or near ARTIZAN STREET  E01000005  City of London 001E
# 1     On or near FLEET STREET  E01032740  City of London 001G
# 2  On or near PLEYDELL STREET  E01032740  City of London 001G
#
#                   Outcome type
# 0     Offender given a caution
# 1  Unable to prosecute suspect
# 2  Unable to prosecute suspect

# %%
dat1=data1.drop(['Crime ID','Month','Falls within','Longitude','Latitude','LSOA code','LSOA name','Reported by'], axis=1)

# %%
dat2=data2.drop(['Crime ID','Month','Falls within','Longitude','Latitude','LSOA code','LSOA name','Reported by'], axis=1)

# %%
dat1.head(4)
# Out:
#                        Location             Crime type Last outcome category  \
# 0    On or near Brownlow Street  Anti-social behaviour                   NaN
# 1          On or near Star Yard  Anti-social behaviour                   NaN
# 2    On or near Brownlow Street  Anti-social behaviour                   NaN
# 3  On or near Pedestrian Subway  Anti-social behaviour                   NaN
#
#    Context
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN

# %%
    dat2.head(4)
# Out:
#                      Location                 Outcome type
# 0   On or near ARTIZAN STREET     Offender given a caution
# 1     On or near FLEET STREET  Unable to prosecute suspect
# 2  On or near PLEYDELL STREET  Unable to prosecute suspect
# 3   On or near Police Station     Offender given a caution

# %%
data1['Crime ID']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      06ad59a65137a97eb1e9e979f1eb96f0d70935e584b3d1...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9      0a89b47eef6f79a7fecde3eba636782f54783c91a74c27...
# 10     9a0c55946ee3af03c5ac9d9329448af954317c897ea3ca...
# 11     1dd469db3a236600afafe7c7d790c196ca82ff54ad569c...
# 12     dbd8d486130bf1ae6cddc3e654874bcbe751fc8dac678e...
# 13     6269c87621c12578331bfdb4890d73db078a57c9b8f7fd...
# 14     e7c9acc7b9ec5e58e1752a11af347c512d21f69e05cd4b...
# 15     54caeb370d9c4e8c722d7fe5b69f8445b5382a8504789e...
# ...

# %%
l=[]
for i in data1['Crime ID']:
    for j in data2['Crime ID']:
        if(i==j):
            l.append(i)

# %%
len(l)
# Out:
# 112

# %%
count=0
for i in l:
    
    if i in data2:
        
           data2.index.values

# %%
data2
# Out:
#                                               Crime ID    Month  \
# 0    9a0874c4253249e9b19acf901553a1b2b283306a7d4e8e...  2016-01
# 1    cedbd8e53be09aedf425960b92532a605f81c5a3d68ecd...  2016-01
# 2    71e4ed14fa7cab036a6a071f05f3ce916c72f9277a2d46...  2016-01
# 3    37d129dcbffc39f2406456cd2db7d327368f43f2956155...  2016-01
# 4    fc64024e2cd4fff34e64e755bc61a05556d28315d91b11...  2016-01
# 5    75e335d991a5eb085420479a9d038ad00c8e3fa9a2d223...  2016-01
# 6    827fc230bc838a300c3acb4436f4ee4cfceef66dfdf152...  2016-01
# 7    2df6f856bca6c389479db341b14681eafc048449d394a4...  2016-01
# 8    83a20851c9195b72da4e521ae36af1b9056e593aa65051...  2016-01
# 9    754345ef727ec05d8e2a03f91094af535fa76dba69718c...  2016-01
# 10   40481ddf24e7fb8b550e400c1d8711c1e3e697e20c211c...  2016-01
# 11   cb09d1dff282a76c7fcc5439dc83912a11776b07e494e2...  2016-01
# 12   f935de2384d794eaf305a3d64842a7c216d69913136fc6...  2016-01
# 13   7f74a01f3acf0a504eca6aded526ca287a30e36871793b...  2016-01
# ...

# %%
dat2=data2.drop(['Crime ID','Month','Falls within','Longitude','Latitude','LSOA code','LSOA name','Reported by'], axis=1)

# %%
dat2
# Out:
#                              Location  \
# 0           On or near ARTIZAN STREET
# 1             On or near FLEET STREET
# 2          On or near PLEYDELL STREET
# 3           On or near Police Station
# 4        On or near Pedestrian Subway
# 5        On or near ST ALPHAGE GARDEN
# 6           On or near NORTON FOLGATE
# 7          On or near ALDERMAN'S WALK
# 8           On or near WATLING STREET
# 9              On or near LIME STREET
# 10   On or near SOUTHAMPTON BUILDINGS
# 11             On or near FETTER LANE
# 12         On or near PLEYDELL STREET
# 13          On or near Police Station
# 14    On or near ST MARTIN'S LE GRAND
# 15          On or near Police Station
# 16       On or near LEADENHALL STREET
# 17          On or near Police Station
# 18          On or near MANSELL STREET
# 19                        No location
# 20            On or near MINCING LANE
# 21               On or near Nightclub
# 22             On or near GRAVEL LANE
# ...

# %%
for i in dat2['Outcome type']:
    if(i=='Investigation complete; no suspect identified'):
          dat2.index

# %%
dat2
# Out:
#                              Location  \
# 0           On or near ARTIZAN STREET
# 1             On or near FLEET STREET
# 2          On or near PLEYDELL STREET
# 3           On or near Police Station
# 4        On or near Pedestrian Subway
# 5        On or near ST ALPHAGE GARDEN
# 6           On or near NORTON FOLGATE
# 7          On or near ALDERMAN'S WALK
# 8           On or near WATLING STREET
# 9              On or near LIME STREET
# 10   On or near SOUTHAMPTON BUILDINGS
# 11             On or near FETTER LANE
# 12         On or near PLEYDELL STREET
# 13          On or near Police Station
# 14    On or near ST MARTIN'S LE GRAND
# 15          On or near Police Station
# 16       On or near LEADENHALL STREET
# 17          On or near Police Station
# 18          On or near MANSELL STREET
# 19                        No location
# 20            On or near MINCING LANE
# 21               On or near Nightclub
# 22             On or near GRAVEL LANE
# ...

# %%
for i in l:
    
    if i in dat2:
        
           dat2.index.values

# %%
dat2
# Out:
#                              Location  \
# 0           On or near ARTIZAN STREET
# 1             On or near FLEET STREET
# 2          On or near PLEYDELL STREET
# 3           On or near Police Station
# 4        On or near Pedestrian Subway
# 5        On or near ST ALPHAGE GARDEN
# 6           On or near NORTON FOLGATE
# 7          On or near ALDERMAN'S WALK
# 8           On or near WATLING STREET
# 9              On or near LIME STREET
# 10   On or near SOUTHAMPTON BUILDINGS
# 11             On or near FETTER LANE
# 12         On or near PLEYDELL STREET
# 13          On or near Police Station
# 14    On or near ST MARTIN'S LE GRAND
# 15          On or near Police Station
# 16       On or near LEADENHALL STREET
# 17          On or near Police Station
# 18          On or near MANSELL STREET
# 19                        No location
# 20            On or near MINCING LANE
# 21               On or near Nightclub
# 22             On or near GRAVEL LANE
# ...

# %%
data2=pd.read_csv('feb 16.csv')

# %%
data2.head()
# Out:
#                                             Crime ID    Month  \
# 0  162c188dc4337ad7807afefa71404c77a66609420f9f5c...  2016-02
# 1                                                NaN  2016-02
# 2                                                NaN  2016-02
# 3  fdc992db4d72023b451af2c8cb283c23d99387c77de6c9...  2016-02
# 4  e909a6e413df4624d8136422fa9bbd20b1fd4deeb48a26...  2016-02
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107607  51.517839
# 1  City of London Police  City of London Police  -0.111497  51.518226
# 2  City of London Police  City of London Police  -0.114954  51.518632
# 3  City of London Police  City of London Police  -0.111497  51.518226
# 4  City of London Police  City of London Police  -0.113767  51.517372
#
#                        Location  LSOA code    LSOA name  \
# 0                On or near A40  E01000917  Camden 027C
# ...

# %%
data3=pd.read_csv('mar 16.csv')

# %%
data3.head()
# Out:
#   Crime ID    Month            Reported by           Falls within  Longitude  \
# 0      NaN  2016-03  City of London Police  City of London Police  -0.095892
# 1      NaN  2016-03  City of London Police  City of London Police  -0.097277
# 2      NaN  2016-03  City of London Police  City of London Police  -0.097334
# 3      NaN  2016-03  City of London Police  City of London Police  -0.097736
# 4      NaN  2016-03  City of London Police  City of London Police  -0.097601
#
#     Latitude                                 Location  LSOA code  \
# 0  51.516391                  On or near Noble Street  E01000001
# 1  51.515307          On or near St Martin'S Le Grand  E01000001
# 2  51.521567                   On or near Fann Street  E01000001
# 3  51.520206  On or near Conference/Exhibition Centre  E01000001
# 4  51.520699             On or near Carthusian Street  E01000001
#
#              LSOA name             Crime type Last outcome category  Context
# ...

# %%
data=data1+data2+data3

# %%
len(data)
# Out:
# 509

# %%
data.head(10)
# Out:
#   Crime ID                  Month  \
# 0      NaN  2016-012016-022016-03
# 1      NaN  2016-012016-022016-03
# 2      NaN  2016-012016-022016-03
# 3      NaN  2016-012016-022016-03
# 4      NaN  2016-012016-022016-03
# 5      NaN  2016-012016-022016-03
# 6      NaN  2016-012016-022016-03
# 7      NaN  2016-012016-022016-03
# 8      NaN  2016-012016-022016-03
# 9      NaN  2016-012016-022016-03
#
#                                          Reported by  \
# 0  City of London PoliceCity of London PoliceCity...
# 1  City of London PoliceCity of London PoliceCity...
# 2  City of London PoliceCity of London PoliceCity...
# 3  City of London PoliceCity of London PoliceCity...
# 4  City of London PoliceCity of London PoliceCity...
# 5  City of London PoliceCity of London PoliceCity...
# 6  City of London PoliceCity of London PoliceCity...
# 7  City of London PoliceCity of London PoliceCity...
# 8  City of London PoliceCity of London PoliceCity...
# ...

# %%
d1=data[data.duplicated(keep =False)]
d1
# Out:
#     Crime ID Month Reported by Falls within  Longitude  Latitude Location  \
# 446      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 447      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 448      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 449      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 450      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 451      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 452      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 453      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 454      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 455      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 456      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 457      NaN   NaN         NaN          NaN        NaN       NaN      NaN
# ...

# %%
data-d1
# Out:
#     Crime ID Month Reported by Falls within  Longitude  Latitude Location  \
# 0        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 1        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 2        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 3        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 4        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 5        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 6        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 7        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 8        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 9        NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 10       NaN   NaN         NaN          NaN        NaN       NaN      NaN
# 11       NaN   NaN         NaN          NaN        NaN       NaN      NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(25,5))

plt.subplot(151)
plt.plot(data[''] / 1000000,file['bedrooms'],'ro')
plt.title('price in millions vs bedrooms')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-217624e2c2cd> in <module>
#       6
#       7 plt.subplot(151)
# ...
